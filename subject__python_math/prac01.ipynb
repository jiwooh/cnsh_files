# %%
from itertools import permutations as nPr
from itertools import product as nΠr
from itertools import combinations as nCr
from itertools import combinations_with_replacement as nHr
from fractions import Fraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=[1,1,2,3,4]
T=set(list(nPr(A,4)))
P=[i for i in T if i[0]<=i[1]<=i[2]<=i[3]]
print(Fraction(len(P),len(T)))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=range(2,15)
B=list(nΠr(A,repeat=4))
C=[i for i in B if all((sum(i)==20, i[1]%i[0]==0, i[2]%i[0]==0, i[3]%i[0]==0))]
print(len(C))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=[1,1,1,0,0,0,0]
B=list(nCr(A,3))
P=[i for i in B if i.count(1)*2>=i.count(0)]
Q=[i for i in B if i.count(1)==2]
print(Fraction(len(Q),len(P)))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=[1,2,3,4,5,6]
T=list(nΠr(A,repeat=3))
P=[i for i in T if i[0]<i[1]-2<=i[2]]
print(Fraction(len(P),len(T)))
# Out:
# 11/108

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=range(0,7)
B=list(nΠr(A,repeat=3))
C=[i for i in B if all((sum(i)==6, i[1]*2!=i[0]+i[2]))]
print(len(C))
# Out:
# 23
