# %%
from itertools import permutations as nPr
from itertools import product as nΠr
from itertools import combinations as nCr
from itertools import combinations_with_replacement as nHr
from fractions import Fraction

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
tw=['aw','bw','cw']
tb=['ab','bb','cb']
W=list(nHr(tw,4))
B=list(nHr(tb,6))
WB=list(nΠr(W,B))
s=[i[0]+i[1] for i in WB]
ss=[]
for i in s:
    f=[x[0] for x in i]
    if f.count('a')>=2 and f.count('b')>=2 and f.count('c')>=2:
        ss.append(i)
print(len(ss))
# Out:
# 168
