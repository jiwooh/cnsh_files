# %%
from itertools import permutations as nPr
from itertools import product as nΠr
from itertools import combinations as nCr
from itertools import combinations_with_replacement as nHr
from fractions import Fraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P=[1,2,3,4,5,'A','B']
T=list(nPr(P,7))
R=[i for i in T if i.index('A')<i.index('B') or abs(i.index('A')-i.index('B'))==3]
print(Fraction(len(R),len(T)))
# Out:
# 25/42
