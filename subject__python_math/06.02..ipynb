# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',10)

# %%
pd.read_csv('./FIFA2018.csv')
# Out:
#            Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0    14-06-2018        Russia  Saudi Arabia            5                 40
# 1    14-06-2018  Saudi Arabia        Russia            0                 60
# 2    15-06-2018         Egypt       Uruguay            0                 43
# 3    15-06-2018       Uruguay         Egypt            1                 57
# 4    15-06-2018       Morocco          Iran            0                 64
# ..          ...           ...           ...          ...                ...
# 123  11-07-2018       England       Croatia            1                 46
# 124  14-07-2018       Belgium       England            2                 43
# 125  14-07-2018       England       Belgium            0                 57
# 126  15-07-2018        France       Croatia            4                 39
# 127  15-07-2018       Croatia        France            2                 61
#
# ...

# %%
pd.read_csv('./SPWSLI.csv', encoding='cp949') #SeoulPublicWifiServiceLocationInfo
# Out:
#            관리번호   자치구    와이파이명         도로명주소        상세주소 설치위치(층)  \
# 0      ARI00001   NaN      NaN           NaN         NaN     NaN
# 1      ARI00002  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# 2      ARI00003   NaN      NaN           NaN         NaN     NaN
# 3      ARI00004  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# 4      ARI00005  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# ...         ...   ...      ...           ...         ...     ...
# 19183  YS170021   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 19184  YS170022   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 19185  YS170023   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 19186  YS170024   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 19187  YS180001   용산구   용산보건분소   원효로1가 26-15     시설관리팀 내      3층
#
#                   설치유형      설치기관        서비스구분         망종류    설치년도 실내외구분  \
# 0                  NaN       NaN          NaN         NaN     NaN   NaN
# ...
