# %%
from itertools import permutations as nPr

# %% [markdown]
# # 1.
# ![prob8](3.19.prob8.png)

# %%
A=['a1','a2','b1','b2','c1','c2','c3']
B=list(nPr(A[:6]))
B=[i+('c3',) for i in B]
print(B)
# Out:
# [('a1', 'a2', 'b1', 'b2', 'c1', 'c2', 'c3'), ('a1', 'a2', 'b1', 'b2', 'c2', 'c1', 'c3'), ('a1', 'a2', 'b1', 'c1', 'b2', 'c2', 'c3'), ('a1', 'a2', 'b1', 'c1', 'c2', 'b2', 'c3'), ('a1', 'a2', 'b1', 'c2', 'b2', 'c1', 'c3'), ('a1', 'a2', 'b1', 'c2', 'c1', 'b2', 'c3'), ('a1', 'a2', 'b2', 'b1', 'c1', 'c2', 'c3'), ('a1', 'a2', 'b2', 'b1', 'c2', 'c1', 'c3'), ('a1', 'a2', 'b2', 'c1', 'b1', 'c2', 'c3'), ('a1', 'a2', 'b2', 'c1', 'c2', 'b1', 'c3'), ('a1', 'a2', 'b2', 'c2', 'b1', 'c1', 'c3'), ('a1', 'a2', 'b2', 'c2', 'c1', 'b1', 'c3'), ('a1', 'a2', 'c1', 'b1', 'b2', 'c2', 'c3'), ('a1', 'a2', 'c1', 'b1', 'c2', 'b2', 'c3'), ('a1', 'a2', 'c1', 'b2', 'b1', 'c2', 'c3'), ('a1', 'a2', 'c1', 'b2', 'c2', 'b1', 'c3'), ('a1', 'a2', 'c1', 'c2', 'b1', 'b2', 'c3'), ('a1', 'a2', 'c1', 'c2', 'b2', 'b1', 'c3'), ('a1', 'a2', 'c2', 'b1', 'b2', 'c1', 'c3'), ('a1', 'a2', 'c2', 'b1', 'c1', 'b2', 'c3'), ('a1', 'a2', 'c2', 'b2', 'b1', 'c1', 'c3'), ('a1', 'a2', 'c2', 'b2', 'c1', 'b1', 'c3'), ('a1', 'a2', 'c2', 'c1', 'b1'
# ...
