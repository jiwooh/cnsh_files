# %%
from bs4 import BeautifulSoup as bs
from pprint import pprint
import requests
import pandas as pd

# %%
html = requests.get('https://open.spotify.com/playlist/37i9dQZEVXbNxXF4SkHj9F')
soup = bs(html.text,'html.parser')
#pprint(soup)

# %%
data1 = soup.findAll('li',{'role':'button'})
#pprint(data1)

title1 = soup.findAll('span',{'class':'track-name'})
#pprint(title1)

title = [title1[i].text for i in range(0,len(title1))]
###print(title)

artist1 = soup.findAll('span',{'class':'artists-albums'})
#pprint(artist1)

base = soup.findAll('li', {'tabindex':'0'})
#pprint(base)

B=[]
for i in range(0,len(base)):
    B.append(base[i])

C=[]
S=[]
T=[]
U=[]
for i in range(0,len(B)):
    x = B[i].findAll('a',{'href': re.compile(r'/artist/')})
    #pprint(x)
    X=[]
    for j in range(0,len(x)):
        X.append(x[j].find('span',{'dir':'auto'}).text)
        #print(X)
        
    y = B[i].findAll('a',{'href': re.compile(r'/album/')})
    #pprint(y)
    Y=[]
    for j in range(0,len(y)):
        Y.append(y[j].find('span',{'dir':'auto'}).text)
        #print(Y)
    #print(title[i])
    
    C.append((title[i], ", ".join(X), ", ".join(Y)))
    S.append(title[i])
    T.append(", ".join(X))
    U.append(", ".join(Y))

#print(C)
print('Spotify 대한민국 차트 #1 to #30')
for i in range(0,len(C)):
    print(f'{i+1}. {C[i][0]} | Artist: {C[i][1]} | Album: {C[i][2]}')
# Out:
# Spotify 대한민국 차트 #1 to #30
# 1. Butter | Artist: BTS | Album: Butter
# 2. Next Level | Artist: aespa | Album: Next Level
# 3. Dynamite | Artist: BTS | Album: BE
# 4. Peaches (feat. Daniel Caesar & Giveon) | Artist: Justin Bieber, Daniel Caesar, Giveon | Album: Justice
# 5. Dun Dun Dance | Artist: OH MY GIRL | Album: Dear OHMYGIRL
# 6. good 4 u | Artist: Olivia Rodrigo | Album: SOUR
# 7. Butter (Instrumental) | Artist: BTS | Album: Butter
# 8. Kiss Me More (feat. SZA) | Artist: Doja Cat, SZA | Album: Kiss Me More (feat. SZA)
# 9. ASAP | Artist: STAYC | Album: STAYDOM
# 10. Life Goes On | Artist: BTS | Album: BE
# 11. LILAC | Artist: IU | Album: IU 5th Album 'LILAC'
# 12. HAPPEN | Artist: HEIZE | Album: HAPPEN
# 13. Butter (Hotter Remix) | Artist: BTS | Album: Butter (Hotter Remix)
# 14. Levitating (feat. DaBaby) | Artist: Dua Lipa, DaBaby | Album: Future Nostalgia
# 15. Leave The Door Open | Artist: Bruno Mars, Anderson .Paak, Silk Sonic | Album: Leave The Door Open
# 16. Save Your Tears (with Ariana Grande) (Remix) | Artist: The Weeknd, Ariana Grande | Album: Save Your Tears (Remix)
# 17. 작은 것들을 위한 시 (Boy With Luv) [feat. Halsey] | Artist: BTS, Halsey | Album: MAP OF THE SOUL : PERSONA
# 18. Rollin' | Artist: Brave Girls | Album: Rollin'
# 19. Celebrity | Artist: IU | Album: IU 5th Album 'LILAC'
# 20. In the morning | Artist: ITZY | Album: GUESS WHO
# 21. Hot Sauce | Artist: NCT DREAM | Album: Hot Sauce - The 1st Album
# 22. MONTERO (Call Me By Your Name) | Artist: Lil Nas X | Album: MONTERO (Call Me By Your Name)
# 23. deja vu | Artist: Olivia Rodrigo | Album: SOUR
# 24. Hold On | Artist: Justin Bieber | Album: Justice
# 25. SUN GOES DOWN | Artist: Lil Nas X | Album: SUN GOES DOWN
# 26. Beautiful Mistakes (feat. Megan Thee Stallion) | Artist: Maroon 5, Megan Thee Stallion | Album: Beautiful Mistakes (feat. Megan Thee Stallion)
# 27. On The Ground | Artist: ROSÉ | Album: R
# 28. Build a Bitch | Artist: Bella Poarch | Album: Build a Bitch
# 29. Black Mamba | Artist: aespa | Album: Black Mamba
# 30. MELODY | Artist: ASH ISLAND | Album: ISLAND

# %%
d={'Song': S, 'Artist': T, 'Album': U}
#print(d)
res=pd.DataFrame(d)
res.index+=1
print('Spotify 대한민국 차트 #1~#30')
res
# Out:
# Spotify 대한민국 차트 #1~#30
#                                               Song  \
# 1                                           Butter
# 2                                       Next Level
# 3                                         Dynamite
# 4           Peaches (feat. Daniel Caesar & Giveon)
# 5                                    Dun Dun Dance
# 6                                         good 4 u
# 7                            Butter (Instrumental)
# 8                         Kiss Me More (feat. SZA)
# 9                                             ASAP
# 10                                    Life Goes On
# 11                                           LILAC
# 12                                          HAPPEN
# 13                           Butter (Hotter Remix)
# 14                       Levitating (feat. DaBaby)
# 15                             Leave The Door Open
# 16    Save Your Tears (with Ariana Grande) (Remix)
# 17       작은 것들을 위한 시 (Boy With Luv) [feat. Halsey]
# 18                                         Rollin'
# 19                                       Celebrity
# 20                                  In the morning
# 21                                       Hot Sauce
# 22                  MONTERO (Call Me By Your Name)
# 23                                         deja vu
# 24                                         Hold On
# 25                                   SUN GOES DOWN
# 26  Beautiful Mistakes (feat. Megan Thee Stallion)
# 27                                   On The Ground
# 28                                   Build a Bitch
# 29                                     Black Mamba
# 30                                          MELODY
#
#                                     Artist  \
# 1                                      BTS
# 2                                    aespa
# 3                                      BTS
# 4     Justin Bieber, Daniel Caesar, Giveon
# 5                               OH MY GIRL
# 6                           Olivia Rodrigo
# 7                                      BTS
# 8                            Doja Cat, SZA
# 9                                    STAYC
# 10                                     BTS
# 11                                      IU
# 12                                   HEIZE
# 13                                     BTS
# 14                        Dua Lipa, DaBaby
# 15  Bruno Mars, Anderson .Paak, Silk Sonic
# 16               The Weeknd, Ariana Grande
# 17                             BTS, Halsey
# 18                             Brave Girls
# 19                                      IU
# 20                                    ITZY
# 21                               NCT DREAM
# 22                               Lil Nas X
# 23                          Olivia Rodrigo
# 24                           Justin Bieber
# 25                               Lil Nas X
# 26           Maroon 5, Megan Thee Stallion
# 27                                    ROSÉ
# 28                            Bella Poarch
# 29                                   aespa
# 30                              ASH ISLAND
#
#                                              Album
# 1                                           Butter
# 2                                       Next Level
# 3                                               BE
# 4                                          Justice
# 5                                    Dear OHMYGIRL
# 6                                             SOUR
# 7                                           Butter
# 8                         Kiss Me More (feat. SZA)
# 9                                          STAYDOM
# 10                                              BE
# 11                            IU 5th Album 'LILAC'
# 12                                          HAPPEN
# 13                           Butter (Hotter Remix)
# 14                                Future Nostalgia
# 15                             Leave The Door Open
# 16                         Save Your Tears (Remix)
# 17                       MAP OF THE SOUL : PERSONA
# 18                                         Rollin'
# 19                            IU 5th Album 'LILAC'
# 20                                       GUESS WHO
# 21                       Hot Sauce - The 1st Album
# 22                  MONTERO (Call Me By Your Name)
# 23                                            SOUR
# 24                                         Justice
# 25                                   SUN GOES DOWN
# 26  Beautiful Mistakes (feat. Megan Thee Stallion)
# 27                                               R
# 28                                   Build a Bitch
# 29                                     Black Mamba
# 30                                          ISLAND

# %%
#artist2 = artist1.find('span',{'dir':'auto'})
#pprint(artist2)
#artist = [ artist2[i].text for i in range(0,len(artist2)) ]
#pprint(artist)

#for i in range(0,len(artist2)):
    #print(artist2[i].text)

#A = [ (artist[3*i], artist[3*i+1], artist[3*i+2]) for i in range(0,len(artist)//3) ]
#print(A)
